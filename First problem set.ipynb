# %%
##Problem 1
wget ftp://ftp.ebi.ac.uk/pub/databases/Pfam/current_release/proteomes/9606.tsv.gz
# Out:
# --2020-11-08 21:11:31--  ftp://ftp.ebi.ac.uk/pub/databases/Pfam/current_release/proteomes/9606.tsv.gz
#            => ‘9606.tsv.gz’
# Resolving ftp.ebi.ac.uk (ftp.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.ebi.ac.uk (ftp.ebi.ac.uk)|193.62.193.138|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /pub/databases/Pfam/current_release/proteomes ... done.
# ==> SIZE 9606.tsv.gz ... 2487458
# ==> PASV ... done.    ==> RETR 9606.tsv.gz ... done.
# Length: 2487458 (2.4M) (unauthoritative)
#
# 100%[======================================>] 2,487,458    611KB/s   in 4.0s
#
# 2020-11-08 21:11:37 (611 KB/s) - ‘9606.tsv.gz’ saved [2487458]

# %%
gunzip 9606.tsv.gz
# Out:
# gzip: 9606.tsv.gz: No such file or directory
# : 1

# %%
# Out:
# 1000565.tsv.gz               linux_data
# 9606.tsv.gz                  linux_data.tar.xz
# bash_class_assignment.ipynb  Mov10_oe_1.subset.fq.fastq
# cb2-101-netinstall.vdi       Mov10_oe_2.subset.fq.fastq
# cb2-101-netinstall.vdi.xz    Mov10_oe_3.subset.fq.fastq
# index.html                   ProblemSet
# Irrel_kd_1.subset.fq.fastq   Problem set 1.ipynb
# Irrel_kd_2.subset.fq.fastq   Untitled1.ipynb
# Irrel_kd_3.subset.fq.fastq   Untitled.ipynb

# %%
ls
# Out:
# 1000565.tsv.gz               linux_data
# 9606.tsv                     linux_data.tar.xz
# bash_class_assignment.ipynb  Mov10_oe_1.subset.fq.fastq
# cb2-101-netinstall.vdi       Mov10_oe_2.subset.fq.fastq
# cb2-101-netinstall.vdi.xz    Mov10_oe_3.subset.fq.fastq
# index.html                   ProblemSet
# Irrel_kd_1.subset.fq.fastq   Problem set 1.ipynb
# Irrel_kd_2.subset.fq.fastq   Untitled1.ipynb
# Irrel_kd_3.subset.fq.fastq   Untitled.ipynb

# %%
# Out:
# 1000565.tsv.gz               Irrel_kd_1.subset.fq.fastq
# 9606.tsv                     Irrel_kd_2.subset.fq.fastq
# AFLN00000000.1.11117.log     Irrel_kd_3.subset.fq.fastq
# all.GeneMark.tar.gz          linux_data
# all.Glimmer3.tar.gz          linux_data.tar.xz
# all.Prodigal.tar.gz          Mov10_oe_1.subset.fq.fastq
# AMHJ00000000.1.11222.log     Mov10_oe_2.subset.fq.fastq
# bash_class_assignment.ipynb  Mov10_oe_3.subset.fq.fastq
# cb2-101-netinstall.vdi       NC_000913.faa
# cb2-101-netinstall.vdi.xz    NZ_AAEK01000176
# class_R.nb.html              practicals (1).rmd
# class_R.Rmd                  practicals.rmd
# ERR                          problem4b
# First problem set.ipynb      ProblemSet
# ftp.ncbi.nlm.nih.gov         Problem set 1.ipynb
# genomes                      ReadMe.txt
# index.html                   SameSpecies.gi
# iris.txt                     Untitled.ipynb

# %%
cat 9606.tsv | cut -f6 | sort | uniq -c | wc -l
# Out:
# 6537

# %%
##Problem 2

# %%
wget -r -A.faa -I genomes/archive/old_refseq/Bacteria/Yersinia_pestis_* \ftp://ftp.ncbi.nlm.nih.gov/genomes/archive/old_refseq/Bacteria/
# Out:
# --2020-11-09 08:24:01--  ftp://ftp.ncbi.nlm.nih.gov/genomes/archive/old_refseq/Bacteria/
#            => ‘ftp.ncbi.nlm.nih.gov/genomes/archive/old_refseq/Bacteria/.listing’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.13, 2607:f220:41e:250::13, 2607:f220:41e:250::12, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.13|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/archive/old_refseq/Bacteria ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
#     [  <=>                                  ] 272,773      512KB/s   in 0.5s
#
# 2020-11-09 08:24:02 (512 KB/s) - ‘ftp.ncbi.nlm.nih.gov/genomes/archive/old_refseq/Bacteria/.listing’ saved [272773]
#
# Removed ‘ftp.ncbi.nlm.nih.gov/genomes/archive/old_refseq/Bacteria/.listing’.
# Rejecting ‘AFLN00000000.1.11117.log’.
# Rejecting ‘AMHJ00000000.1.11222.log’.
# Rejecting ‘CLUSTERS’.
# ...

# %%
## /media/sf_matthewcheung/Documents/CB2-101/ftp.ncbi.nlm.nih.gov/genomes/archive/old_refseq/Bacteria
ls
# Out:
# Yersinia_pestis_A1122_uid158119
# Yersinia_pestis_Angola_uid58485
# Yersinia_pestis_Antiqua_uid58607
# Yersinia_pestis_biovar_Medievalis_Harbin_35_uid158537
# Yersinia_pestis_biovar_Microtus_91001_uid58037
# Yersinia_pestis_CO92_uid57621
# Yersinia_pestis_D106004_uid158071
# Yersinia_pestis_D182038_uid158073
# Yersinia_pestis_KIM_10_uid57875
# Yersinia_pestis_Nepal516_uid58609
# Yersinia_pestis_Pestoides_F_uid58619
# Yersinia_pestis_Z176003_uid47317

# %%
# Out:
# cat: invalid option -- '.'
# Try 'cat --help' for more information.
# 0

# %%
# Out:
# /media/sf_matthewcheung/Documents/CB2-101/ftp.ncbi.nlm.nih.gov/genomes/archive/old_refseq/Bacteria

# %%
##Problem 3

# %%
#How to do for one file
cat /media/sf_matthewcheung/Documents/CB2-101/ftp.ncbi.nlm.nih.gov/genomes/archive/old_refseq/Bacteria/Yersinia_pestis_A1122_uid158119/*.faa | grep "^>" | wc -l
# Out:
# 4247

# %%
##Find in this area, file names .faa, normal type, execute cat on the file, grab the > for proteins, and count
find /media/sf_matthewcheung/Documents/CB2-101/ftp.ncbi.nlm.nih.gov/genomes/archive/old_refseq/Bacteria/ -name "*.faa" -type f -exec cat {} \; | grep "^>" | wc -l
# Out:
# 48772

# %%
## Problem 4

# %%
wget ftp://ftp.ncbi.nlm.nih.gov/genomes/archive/old_refseq/Bacteria/Escherichia_coli_K_12_substr__MG1655_uid57779/NC_000913.faa
# Out:
# --2020-11-08 22:27:21--  ftp://ftp.ncbi.nlm.nih.gov/genomes/archive/old_refseq/Bacteria/Escherichia_coli_K_12_substr__MG1655_uid57779/NC_000913.faa
#            => ‘NC_000913.faa’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.7, 2607:f220:41e:250::10, 2607:f220:41e:250::11, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.7|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/archive/old_refseq/Bacteria/Escherichia_coli_K_12_substr__MG1655_uid57779 ... done.
# ==> SIZE NC_000913.faa ... 1822571
# ==> PASV ... done.    ==> RETR NC_000913.faa ... done.
# Length: 1822571 (1.7M) (unauthoritative)
#
# 100%[======================================>] 1,822,571   4.13MB/s   in 0.4s
#
# 2020-11-08 22:27:22 (4.13 MB/s) - ‘NC_000913.faa’ saved [1822571]

# %%
echo $(cat NC_000913.faa | grep -v "^>" | tr -d "\n"| wc -c) /$(cat NC_000913.faa | grep "^>" | wc -l) |  bc
# Out:
# 316

# %%
##Run bash problem4b __FILE NAME__
bash problem4b NC_000913.faa
# Out:
# 316
